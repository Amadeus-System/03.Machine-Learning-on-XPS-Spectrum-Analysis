# %%
# Library import
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
N = 3  # Maximum number of possible peak
Data_size = 200000 

Parameters = np.zeros((Data_size, N, 2))  # Set of Parameters ready
print(Parameters.shape[1])
# Out:
# 5

# %%
# Lorentzian function that returns sum of multi-Lorentzian function with two arguments
def Lorentzian(x, *args):
    ''' returns sum of Multi-Lorentzian function 
    corresponding to each two arguments (a, b)'''
    a = args[::3]
    b = args[1::3]
    c = args[2::3]

    result = 0
    for i in range(len(a)):
        if a[i] > 0 and b[i] > 0:
            if len(a) == len(b):
                result += b[i] / ((x - a[i])**2 + b[i]**2)

    for xx in range(len(result)):
        result[xx] += 0.1* ((np.random.rand()*2) - 1)

    return result 
    # noise = -0.2 ~ 0.2

# %%
# X domain fixed
x = np.arange(-2, 4, 0.01)
print(len(x))
# Out:
# 600

# %%
for i in range(len(Parameters)): # For each matrix in Parameter set...

    for j in range(Parameters.shape[1]): # For each raw in each matrix...
        
        # append two argument that will be used in Lorentzian function
        # Second parameter is constrained in range from 0.1 to 0.2
        a = np.random.rand()
        Parameters[i][0] = np.array([[a, 0.1*np.random.rand() + 0.1]])
        Parameters[i][1] = np.array([[a + 2, 0.1*np.random.rand()+0.1]])
    
# Check out
print(Parameters)
# Out:
# [[[ 0.24430277  0.19501951]
#   [ 2.24430277  0.15979948]
#   [ 4.24430277  0.11799043]
#   [ 6.24430277  0.19983187]
#   [10.24430277  0.13020514]]
#
#  [[ 0.20203109  0.18509037]
#   [ 2.20203109  0.18863825]
#   [ 4.20203109  0.16916446]
#   [ 6.20203109  0.10613313]
#   [10.20203109  0.11517755]]
#
#  [[ 0.15808312  0.10367025]
#   [ 2.15808312  0.14663543]
#   [ 4.15808312  0.11044952]
#   [ 6.15808312  0.19769723]
#   [10.15808312  0.16540803]]
#
#  ...
#
#  [[ 0.69334467  0.19434353]
#   [ 2.69334467  0.12917735]
#   [ 4.69334467  0.1682108 ]
#   [ 6.69334467  0.1397746 ]
#   [10.69334467  0.11605797]]
#
#  [[ 0.8551072   0.18735508]
#   [ 2.8551072   0.10471942]
#   [ 4.8551072   0.11839171]
#   [ 6.8551072   0.19223497]
#   [10.8551072   0.1087752 ]]
#
#  [[ 0.45527916  0.12838154]
#   [ 2.45527916  0.14874218]
#   [ 4.45527916  0.15069107]
#   [ 6.45527916  0.11430935]
#   [10.45527916  0.12336908]]]

# %%
# ================== Data Generating ================
Data_x = []
Data_y = []

for j in Parameters:  # For each parameter matrix...

    peak = random.randint(2, N) # Random selection of Possible peak number
    j = list(j.reshape((2*N,))) # reshape processing to put it as *args in function, Since j is matrix

    if peak == 1:
        Data_x.append(Lorentzian(x, *j[0:2]))
        Data_y.append(np.array([sum(Lorentzian(x, *j[0:2])), peak]))

    elif peak == 2:
        Data_x.append(Lorentzian(x, *j[0:4]))
        Data_y.append(np.array([j[0], j[1], j[2], j[3]]))

    elif peak == 3:
        Data_x.append(Lorentzian(x, *j[0:6]))
        Data_y.append(np.array([sum(Lorentzian(x, *j[0:6])) ,peak]))

    elif peak == 4:
        Data_x.append(Lorentzian(x, *j[0:8]))
        Data_y.append(np.array([sum(Lorentzian(x, *j[0:8])), peak]))

    elif peak == 5:
        Data_x.append(Lorentzian(x, *j[0:]))
        Data_y.append(np.array([sum(Lorentzian(x, *j[0:])), peak]))

# %%
# Generated Data sample check!
plt.figure(figsize=(12, 6))

for i in range(3):
    plt.plot(x, Data_x[i], label = str(i) + '-th data')
    plt.legend()
    plt.grid('on')

# %%
x.shape
x = x.reshape(600)
x.shape
# Out:
# (600,)

# %%
# Data spliting up into three group : training/validation/test

train_data = np.array(Data_x[:100000])
val_data = np.array(Data_x[100000:150000])
test_data = np.array(Data_x[150000:])

train_labels = np.array(Data_y[:100000])
val_labels = np.array(Data_y[100000:150000])
test_labels = np.array(Data_y[150000:])

# %%
# size test

print(train_data.shape, train_labels.shape)
print(val_data.shape, val_labels.shape)
print(test_data.shape, test_labels.shape)
# Out:
# (100000, 600) (100000, 4)
# (50000, 600) (50000, 4)
# (50000, 600) (50000, 4)

# %%
# reshape for Image-form setting
# 2차원일때만!
#train_data = train_data.reshape(100000, 20, 20, 1)
#val_data = val_data.reshape(150000, 20, 20, 1)
#test_data = test_data.reshape(50000, 20, 20, 1)

# %%
# reshape for Image-form setting
# 1차원일때 변환
train_data = train_data.reshape(100000, 600, 1)
val_data = val_data.reshape(50000, 600, 1)
test_data = test_data.reshape(50000, 600, 1)

# %%
# From Here on, let`s start to make Convolution Neural Network!
# Library import
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# Modeling
model2 = Sequential()

model2.add(Conv1D(8, 50, activation='relu', input_shape=(600, 1)))
model2.add(MaxPooling1D(2)) 

model2.add(Conv1D(8, 40, activation='relu'))
model2.add(MaxPooling1D(2)) 

# Fully-Connected Layers
model2.add(GlobalMaxPooling1D())
model2.add(Dense(100, activation = 'relu'))
#model2.add(Dropout(0.3))
model2.add(Dense(4))

model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 551, 8)            408
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 275, 8)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 236, 8)            2568
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 118, 8)            0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 100)               900
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 404
# =================================================================
# Total params: 4,280
# Trainable params: 4,280
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss='mse', metrics=['mae'], optimizer=Adam())

# %%
# %%time
hist2 = model2.fit(train_data, train_labels, 
                   epochs=50, 
                   batch_size=2000,
                   validation_data=(val_data, val_labels), verbose=1)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 1s 26ms/step - loss: 0.2732 - mae: 0.3235 - val_loss: 0.0525 - val_mae: 0.1494
# Epoch 2/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0438 - mae: 0.1389 - val_loss: 0.0346 - val_mae: 0.1257
# Epoch 3/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0233 - mae: 0.1052 - val_loss: 0.0132 - val_mae: 0.0820
# Epoch 4/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0100 - mae: 0.0689 - val_loss: 0.0081 - val_mae: 0.0606
# Epoch 5/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0078 - mae: 0.0587 - val_loss: 0.0073 - val_mae: 0.0564
# Epoch 6/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0073 - mae: 0.0564 - val_loss: 0.0070 - val_mae: 0.0550
# Epoch 7/50
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0070 - mae: 0.0551 - val_loss: 0.0066 - val_mae: 0.0530
# Epoch 8/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0064 - mae: 0.0525 - val_loss: 0.0059 - val_mae: 0.0508
# Epoch 9/50
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0059 - mae: 0.0508 - val_loss: 0.0056 - val_mae: 0.0496
# Epoch 10/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0055 - mae: 0.0497 - val_loss: 0.0052 - val_mae: 0.0481
# Epoch 11/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0051 - mae: 0.0476 - val_loss: 0.0051 - val_mae: 0.0474
# Epoch 12/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0049 - mae: 0.0458 - val_loss: 0.0049 - val_mae: 0.0454
# Epoch 13/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0046 - mae: 0.0435 - val_loss: 0.0044 - val_mae: 0.0420
# Epoch 14/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0043 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0404
# Epoch 15/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0038 - mae: 0.0388 - val_loss: 0.0034 - val_mae: 0.0364
# Epoch 16/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0034 - mae: 0.0364 - val_loss: 0.0032 - val_mae: 0.0350
# Epoch 17/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0032 - mae: 0.0352 - val_loss: 0.0032 - val_mae: 0.0353
# Epoch 18/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0031 - mae: 0.0342 - val_loss: 0.0030 - val_mae: 0.0341
# Epoch 19/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0030 - mae: 0.0341 - val_loss: 0.0029 - val_mae: 0.0334
# Epoch 20/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0029 - mae: 0.0332 - val_loss: 0.0028 - val_mae: 0.0324
# Epoch 21/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0028 - mae: 0.0322 - val_loss: 0.0027 - val_mae: 0.0314
# Epoch 22/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0027 - mae: 0.0318 - val_loss: 0.0026 - val_mae: 0.0311
# Epoch 23/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0027 - mae: 0.0317 - val_loss: 0.0026 - val_mae: 0.0312
# Epoch 24/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0026 - mae: 0.0310 - val_loss: 0.0025 - val_mae: 0.0302
# Epoch 25/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0025 - mae: 0.0305 - val_loss: 0.0025 - val_mae: 0.0303
# Epoch 26/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0025 - mae: 0.0302 - val_loss: 0.0025 - val_mae: 0.0298
# Epoch 27/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0024 - mae: 0.0299 - val_loss: 0.0024 - val_mae: 0.0297
# Epoch 28/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0024 - mae: 0.0298 - val_loss: 0.0023 - val_mae: 0.0291
# Epoch 29/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0023 - mae: 0.0294 - val_loss: 0.0023 - val_mae: 0.0286
# Epoch 30/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0023 - mae: 0.0289 - val_loss: 0.0023 - val_mae: 0.0294
# Epoch 31/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0023 - mae: 0.0289 - val_loss: 0.0022 - val_mae: 0.0288
# Epoch 32/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0022 - mae: 0.0286 - val_loss: 0.0022 - val_mae: 0.0278
# Epoch 33/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0022 - mae: 0.0284 - val_loss: 0.0022 - val_mae: 0.0279
# Epoch 34/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0022 - mae: 0.0279 - val_loss: 0.0021 - val_mae: 0.0274
# Epoch 35/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0021 - mae: 0.0277 - val_loss: 0.0021 - val_mae: 0.0275
# Epoch 36/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0021 - mae: 0.0275 - val_loss: 0.0021 - val_mae: 0.0274
# Epoch 37/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0021 - mae: 0.0276 - val_loss: 0.0022 - val_mae: 0.0276
# Epoch 38/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0021 - mae: 0.0274 - val_loss: 0.0021 - val_mae: 0.0269
# Epoch 39/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0020 - mae: 0.0270 - val_loss: 0.0020 - val_mae: 0.0265
# Epoch 40/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0020 - mae: 0.0269 - val_loss: 0.0020 - val_mae: 0.0266
# Epoch 41/50
# 50/50 [==============================] - 1s 23ms/step - loss: 0.0020 - mae: 0.0267 - val_loss: 0.0020 - val_mae: 0.0262
# Epoch 42/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0020 - mae: 0.0268 - val_loss: 0.0020 - val_mae: 0.0263
# Epoch 43/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0020 - mae: 0.0266 - val_loss: 0.0020 - val_mae: 0.0262
# Epoch 44/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0019 - mae: 0.0261 - val_loss: 0.0019 - val_mae: 0.0261
# Epoch 45/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0019 - mae: 0.0261 - val_loss: 0.0019 - val_mae: 0.0260
# Epoch 46/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0019 - mae: 0.0259 - val_loss: 0.0019 - val_mae: 0.0258
# Epoch 47/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0019 - mae: 0.0262 - val_loss: 0.0019 - val_mae: 0.0258
# Epoch 48/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0020 - mae: 0.0275 - val_loss: 0.0021 - val_mae: 0.0279
# Epoch 49/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0019 - mae: 0.0256 - val_loss: 0.0019 - val_mae: 0.0255
# Epoch 50/50
# 50/50 [==============================] - 1s 22ms/step - loss: 0.0018 - mae: 0.0252 - val_loss: 0.0018 - val_mae: 0.0250
# CPU times: user 48 s, sys: 15.7 s, total: 1min 3s
# Wall time: 59.2 s

# %%
# Loss plot
plt.plot(hist2.history['loss'][1:], 'b-', label="training")
plt.plot(hist2.history['val_loss'][1:], 'r:', label="validation")
plt.grid(True)
plt.legend()
plt.show()

# %%
predict = model2.predict(test_data)
predict.shape
# Out:
# (50000, 4)

# %%
for i in range(10):
    print(predict[i])
    print(test_labels[i])
    print('==============')
# Out:
# [0.3534469  0.10145207 2.345888   0.13376786]
# [0.39828062 0.10777624 2.39828062 0.13537949]
# ==============
# [0.02158619 0.17815673 2.0065491  0.17008635]
# [0.02445861 0.17379693 2.02445861 0.18230084]
# ==============
# [0.8523514  0.14290856 2.8327854  0.12515885]
# [0.82782063 0.14504518 2.82782063 0.12962463]
# ==============
# [0.6929036  0.14085096 2.6780624  0.1108349 ]
# [0.82754748 0.14139485 2.82754748 0.1112167 ]
# ==============
# [0.09685074 0.09688673 2.1004112  0.14981234]
# [0.12192078 0.10492667 2.12192078 0.16996547]
# ==============
# [0.70155495 0.15340975 2.6996953  0.11757287]
# [0.72745357 0.1568759  2.72745357 0.12349074]
# ==============
# [0.47749832 0.10328851 2.4812586  0.17686357]
# [0.49206493 0.11031117 2.49206493 0.17490397]
# ==============
# [0.02037485 0.14976746 2.0152478  0.16675094]
# [0.05067142 0.1410298  2.05067142 0.18632074]
# ==============
# [0.90859044 0.19379497 2.874008   0.1264303 ]
# [0.8581281  0.18227703 2.8581281  0.14696171]
# ==============
# [0.05092038 0.15617283 2.0309463  0.11472681]
# [0.00773206 0.15764949 2.00773206 0.10716426]
# ==============

# %%
def simple(x, *args):
    ''' returns sum of Multi-Lorentzian function 
    corresponding to each two arguments (a, b)'''
    a = args[::2]
    b = args[1::2]

    result = 0
    for i in range(len(a)):
        if a[i] > 0 and b[i] > 0:
            if len(a) == len(b):
                result += b[i] / ((x - a[i])**2 + b[i]**2)

    return result

# %%
for i in range(20):
    plt.figure(figsize=(12,5))
    plt.plot(x, Lorentzian(x, *list(predict[i])), label=str(i)+'-th predict')
    plt.plot(x, test_data[i], label=str(i)+'-th label')
    #plt.plot(x, simple(x, *list(predict[i])), label=str(i)+'-th exact')
    plt.legend()
    plt.show()

# %%
# Check the architecture of the CNN
print(model2.layers[0])
print(model2.layers[1])
print(model2.layers[2])
print(model2.layers[3])
print(model2.layers[4])
print(model2.layers[5])
#print(model2.layers[6])
#print(model2.layers[7])
# Out:
# <tensorflow.python.keras.layers.convolutional.Conv1D object at 0x7fb8b37239b0>
# <tensorflow.python.keras.layers.pooling.MaxPooling1D object at 0x7fb8b3339940>
# <tensorflow.python.keras.layers.convolutional.Conv1D object at 0x7fb8b337ed68>
# <tensorflow.python.keras.layers.pooling.MaxPooling1D object at 0x7fb8a00aacc0>
# <tensorflow.python.keras.layers.pooling.GlobalMaxPooling1D object at 0x7fb8a00aae80>
# <tensorflow.python.keras.layers.core.Dense object at 0x7fb8a00aae48>

# %%
for i in range(7):
    print(str(i) +'-th layer :', len(model2.layers[i].get_weights()))
# Out:
# 0-th layer : 2
# 1-th layer : 0
# 2-th layer : 2
# 3-th layer : 0
# 4-th layer : 0
# 5-th layer : 2
# 6-th layer : 2

# %%
layer_0 = model2.layers[0].get_weights()

layer_2 = model2.layers[2].get_weights()

layer_5 = model2.layers[5].get_weights()

layer_6 = model2.layers[6].get_weights()

# %%
# 첫번째 컨볼루션 필터
filter_0 = layer_0[0]
filter_0.shape # 16개의 필터가 커널사이즈 10으로 존재함
# Out:
# (50, 1, 8)

# %%
# 2번째 컨볼루션 필터
filter_2 = layer_2[0]
filter_2.shape
# Out:
# (40, 8, 8)

# %%
# 완전연결층
layer_5[1].shape
# Out:
# (100,)

# %%
# 첫번째 컨볼루션 필터 시각화
M = 8
plt.figure(figsize=(14, 6))

for i in range(M):  
    plt.subplot(1, M, i + 1)  # Subplot : from 1 to 8
    plt.imshow(filter_0[ :, :,i]) # 1st-conv filter showing
    plt.grid(False)

# %%
# 두번째 컨볼루션 필터 시각화
M = 8
plt.figure(figsize=(18, 6))

for i in range(M):
    plt.subplot(1, M, i + 1)  # Subplot from 1 to 8
    plt.imshow(filter_2[:, :, i]) # (10, 16) filter showing -> (10, 16) = (10, 1)filter * 16
    plt.grid(False)

# %%
# 각각의 레이어에서의 출력을 확인하기
import tensorflow.keras.backend as K

# Outputs of each layers
f0 = K.function([model2.input], [model2.layers[0].output])
f1 = K.function([model2.input], [model2.layers[1].output])
f2 = K.function([model2.input], [model2.layers[2].output])
f3 = K.function([model2.input], [model2.layers[3].output])
f4 = K.function([model2.input], [model2.layers[4].output])
f5 = K.function([model2.input], [model2.layers[5].output])
f6 = K.function([model2.input], [model2.layers[6].output])
#f7 = K.function([model2.input], [model2.layers[7].output])

# %%
n = 0
x = train_data[n:n+1]

x.shape
# Out:
# (1, 600, 1)

# %%
plt.figure(figsize=(14, 3))  # 피규어 생성하고

for i in range(3): 
    plt.subplot(1, 3, i + 1)  # three Subplot generated
    if i == 1:                # center plot
        plt.plot(x[0])        # image showed
    else:  
        plt.plot(np.zeros_like(x[0]))  # zero image
        plt.axis("off")
plt.tight_layout()
plt.suptitle("Input data", y=1)
# Out:
# Text(0.5, 1, 'Input data')

# %%
# 1번째 컨볼루션 층 출력결과
z0 = f0([x])[0]
z0.shape
# Out:
# (1, 551, 8)

# %%
plt.figure(figsize=(20, 4))

for i in range(8):
    plt.subplot(1, 8, i + 1)
    plt.plot(z0[0, :, i])
    plt.axis('on')
    
    plt.title("{}-th Filter passed".format(i))
plt.tight_layout()
plt.suptitle("After Cnvolution filter", y=1.1)
# Out:
# Text(0.5, 1.1, 'After Cnvolution filter')

# %%
# 2번째 맥스풀링층 출력 결과
z1 = f1([x])[0]
print(z1.shape)
# Out:
# (1, 275, 8)

# %%
plt.figure(figsize=(20, 3))

for i in range(8):
    plt.subplot(1, 8, i + 1)
    plt.plot(z1[0, :, i])
    
    plt.title("{}-th MaxPooling passed".format(i))
plt.tight_layout()
plt.suptitle("After MaxPooling1D", y=1.1)
# Out:
# Text(0.5, 1.1, 'After MaxPooling1D')

# %%
# 3번째 컨볼루션 층 출력결과
z2 = f2([x])[0]
print(z2.shape)
# Out:
# (1, 236, 8)

# %%
plt.figure(figsize=(20, 3))

for i in range(8):
    plt.subplot(1, 8, i + 1)
    plt.plot(z2[0, :, i])
    
    plt.title("{}-th Conv passed".format(i))
plt.tight_layout()
plt.suptitle("After 2nd Conv1D", y=1.1)
# Out:
# Text(0.5, 1.1, 'After 2nd Conv1D')

# %%
# 4번째 MaxPooling 층 출력결과
z3 = f3([x])[0]
print(z3.shape)
# Out:
# (1, 118, 8)

# %%
plt.figure(figsize=(20, 3))

for i in range(8):
    plt.subplot(1, 8, i + 1)
    plt.plot(z3[0, :, i])
    
    plt.title("{}-th maxpooling passed".format(i))
plt.tight_layout()
plt.suptitle("After 2nd MaxPooling", y=1.1)
# Out:
# Text(0.5, 1.1, 'After 2nd MaxPooling')

# %%
# 5번째층 GlobalMaxPooling층 출력 결과
z4 = f4([x])[0]
print(z4.shape)
print(z4)
# Out:
# (1, 8)
# [[0.8774236  3.2129307  0.77363235 0.         3.3661776  0.71021676
#   4.517044   4.429311  ]]

# %%
plt.figure(figsize=(10, 3))
plt.imshow(z4, aspect=10)
plt.xticks([]); plt.yticks([]); plt.grid(False)
plt.title("vectorizing")
# Out:
# Text(0.5, 1.0, 'vectorizing')

# %%
# 6번째층 Dense Layer(Fully Connected Layer) 출력 결과
z5 = f5([x])[0]
print(z5.shape)

plt.figure(figsize=(12, 4))
plt.imshow(z5)
plt.show()

plt.figure(figsize=(12, 4))
plt.plot(z5[0])
plt.show()
# Out:
# (1, 100)

# %%
# 7번째 Dropout 층 출력 결과
z6 = f6([x])[0]
print(z6.shape)

plt.figure(figsize=(12, 4))
plt.imshow(z6)
plt.show()


plt.figure(figsize=(12, 4))
plt.plot(z6[0])
plt.show()
# Out:
# (1, 4)

# %%
# 8번째 최종출력층 출력 결과
z7 = f7([x])[0]
print(z7)

plt.figure(figsize=(10,2))
plt.imshow(z7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-d813697e4263> in <module>()
# ----> 1 z7 = f7([x])[0]
#       2 print(z7)
#       3
#       4 plt.figure(figsize=(10,2))
#       5 plt.imshow(z7)
#
# NameError: name 'f7' is not defined

# %%
# 1차원 데이터에 대응되는 라벨은 뭘로? => 적분값과 peak 수는 안정적인 라벨로 작용, 하지만 목적에 안맞는다.
# 라벨 -> 원래 의도대로 mean position, width로 되돌림
# 로렌치안 함수 정의에 약간의 오류 발견 -> 수정, 재시도하였음
# 이전보다 상당히 나아진 듯, 

# 해석하기 어려운 것
# 각 컨볼루션 층에서의 필터가 의미하는 것?? -> 시각화해도 의미를 설명하기 어렵다.
# 각각의 레이어의 정보를 완전히 표현하는 방법 좀 더 공부..
